# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak-1440/exception-handling-/blob/main/handlingutlier_o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 5 number summary
1.minimum value
2.Q1=25%
3. MEDIAN
4. Q3=75 PERCENTILE
5. MAXIMUM
# Out:
#   File "/tmp/ipython-input-2763504953.py", line 2
#     1.minimum value
#      ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np
lst_marks = [45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,1000,1100]
np.percentile(lst_marks,[25])
# Out:
# array([54.])

# %%
##lower_fence<--->higher_fence
Q1 = np.percentile(lst_marks, [25])
Q1
# Out:
# array([54.])

# %%
minimum, Q1, Q2, Q3, maximum = np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])
##IN THIS OUTLIERS ARE INCLUDED

# %%
minimum
# Out:
# np.float64(32.0)

# %%
maximum
# Out:
# np.float64(1100.0)

# %%
Q1
# Out:
# np.float64(54.0)

# %%
Q2
# Out:
# np.float64(74.0)

# %%
Q3
# Out:
# np.float64(89.5)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 35.5

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(0.75)

# %%
higher_fence
# Out:
# np.float64(142.75)

# %%
outliers = []
for i in lst_marks:
  if i>=0.75 and i<=142.75:
    print("this element is not an outlier")
  else:
    outliers.append(i)
# Out:
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier
# this element is not an outlier

# %%
outliers
# Out:
# [1000, 1100]

# %%
##BOXPLOTMETHOD
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
