# %%
try :
    f = open("test.txt" , "r")
    f.write("this is my pen")
except Exception as e:
    print("laptop is working well" , e)
# Out:
# laptop is working well not writable

# %%
try:
    file = open("test2.txt" ,"r")
    f.write("harsh is good boy")
except Exception as e:
    print(" i am a good boy" , e)
# Out:
#  i am a good boy [Errno 44] No such file or directory: 'test2.txt'

# %%
try:
    a=10
    b=0
    c=a/b
except Exception as e:
    print("hello world" , e)
# Out:
# hello world division by zero

# %%
try:
    a = int(input("enter the first number "))
    b = int(input("enter the second number"))
    c = a/b
except Exception as e:
    print("you may fail in this " ,e)
# Out:
# enter the first number  6
# enter the second number 0
# you may fail in this  division by zero

# %%
try :
    a = int(input("enter the first side of triangle"))
    b = int(input("enter second side of triangle"))
    c = int(input("enter the third side"))
    d = (a+b)/c
except Exception as e :
    print("this theb best  way" ,e)
# Out:
# enter the first side of triangle 5
# enter second side of triangle 6
# enter the third side 0
# this theb best  way division by zero

# %%
try :
    a = int(input("enter the number"))
    b = int(input("enter the number"))
    c = a/b
except Exception as e :
    print("you may fail" , e)
else :
    print("you may succeed")
# Out:
# enter the number 5
# enter the number 5
# you may succeed

# %%
try :
